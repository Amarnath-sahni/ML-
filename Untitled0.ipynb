# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarnath-sahni/AMAR/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a2bb7b5c-1e0c-4a41-91fb-fa8ebc81b557" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2bb7b5c-1e0c-4a41-91fb-fa8ebc81b557">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df= pd.read_csv('Diabetes Missing Data.csv')
print(df.head())
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
x = df["Serum_Insulin"].mean()

df["Serum_Insulin"].fillna(x, inplace = True)
print(df.head())
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0     155.548223  33.6
# 1         1     85.0          66.0       29.0     155.548223  26.6
# 2         8    183.0          64.0        NaN     155.548223  23.3
# 3         1     89.0          66.0       23.0      94.000000  28.1
# 4         0    137.0          40.0       35.0     168.000000  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1
# <ipython-input-7-d2144b49609f>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6bbbeb46-0bbd-4757-a182-6f426252d10c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bbbeb46-0bbd-4757-a182-6f426252d10c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df= pd.read_csv('Diabetes Missing Data.csv')
print(df.head())
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
x = df["Serum_Insulin"].median()

df["Serum_Insulin"].fillna(x, inplace = True)
print(df.head())
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0          125.0  33.6
# 1         1     85.0          66.0       29.0          125.0  26.6
# 2         8    183.0          64.0        NaN          125.0  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1
# <ipython-input-13-70be0efdd9b7>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d859ebc-c423-46c7-bfdd-918769818dc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d859ebc-c423-46c7-bfdd-918769818dc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('Diabetes Missing Data (2).csv')
print(df.head())
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
x = df["Serum_Insulin"].mode()[0]

df["Serum_Insulin"].fillna(x, inplace = True)
print(df.head())
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0          105.0  33.6
# 1         1     85.0          66.0       29.0          105.0  26.6
# 2         8    183.0          64.0        NaN          105.0  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1
# <ipython-input-16-39a414067d39>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('Diabetes Missing Data (2).csv')
print(df.corr())
# Out:
#                    Pregnant   Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin  \
# Pregnant           1.000000  0.128135      0.214178   0.100239       0.082171
# Glucose            0.128135  1.000000      0.223192   0.228043       0.581186
# Diastolic_BP       0.214178  0.223192      1.000000   0.226839       0.098272
# Skin_Fold          0.100239  0.228043      0.226839   1.000000       0.184888
# Serum_Insulin      0.082171  0.581186      0.098272   0.184888       1.000000
# BMI                0.021719  0.232771      0.289230   0.648214       0.228050
# Diabetes_Pedigree -0.033523  0.137246     -0.002805   0.115016       0.130395
# Age                0.544341  0.267136      0.330107   0.166816       0.220261
# Class              0.221898  0.494650      0.170589   0.259491       0.303454
#
#                         BMI  Diabetes_Pedigree       Age     Class
# Pregnant           0.021719          -0.033523  0.544341  0.221898
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

print(df.corr())
# Remove extra spaces from column names
df["Pregnant"].plot(kind = 'hist')
#df.plot(kind = 'scatter', x = 'Pregnant', y = 'Glucose')
plt.plot()
plt.show()
# Out:
#                    Pregnant   Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin  \
# Pregnant           1.000000  0.128135      0.214178   0.100239       0.082171
# Glucose            0.128135  1.000000      0.223192   0.228043       0.581186
# Diastolic_BP       0.214178  0.223192      1.000000   0.226839       0.098272
# Skin_Fold          0.100239  0.228043      0.226839   1.000000       0.184888
# Serum_Insulin      0.082171  0.581186      0.098272   0.184888       1.000000
# BMI                0.021719  0.232771      0.289230   0.648214       0.228050
# Diabetes_Pedigree -0.033523  0.137246     -0.002805   0.115016       0.130395
# Age                0.544341  0.267136      0.330107   0.166816       0.220261
# Class              0.221898  0.494650      0.170589   0.259491       0.303454
#
#                         BMI  Diabetes_Pedigree       Age     Class
# Pregnant           0.021719          -0.033523  0.544341  0.221898
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd


# Define feature names
features = ["Pregnant", "Glucose", "Diastolic_BP", "Skin_Fold", "Serum_Insulin",
            "BMI", "Diabetes_Pedigree", "Age", "Class"]

# Convert to DataFrame
df_corr = pd.DataFrame(corr_matrix, index=features, columns=features)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


data= df.corr()
# Convert to DataFrame
df_corr = pd.DataFrame(data, index=data.keys())

# Plot heatmap
plt.figure(figsize=(8, 6))
plt.imshow(df_corr, cmap="coolwarm", interpolation="nearest")
plt.colorbar()
plt.xticks(range(len(df_corr)), df_corr.columns, rotation=45)
plt.yticks(range(len(df_corr)), df_corr.columns)
plt.title("Correlation Matrix")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(df_corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()
